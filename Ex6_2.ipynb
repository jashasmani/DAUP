# %% [markdown]
# <a href="https://colab.research.google.com/github/jashasmani/DAUP/blob/main/Ex6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.Import necessary packages
import pandas as pd
import numpy as np
import sklearn.datasets as data
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv('/content/weather.csv')
df

df['play']=df['play'].replace(to_replace='yes',value=1)
df['play']=df['play'].replace(to_replace='no',value=0)
df['windy']=df['windy'].replace(to_replace=False,value=0)
df['windy']=df['windy'].replace(to_replace=True,value=1)
df['humidity']=df['humidity'].replace(to_replace='high',value=0)
df['humidity']=df['humidity'].replace(to_replace='normal',value=1)
df['temperature']=df['temperature'].replace(to_replace='hot',value=0)
df['temperature']=df['temperature'].replace(to_replace='cool',value=2)
df['temperature']=df['temperature'].replace(to_replace='mild',value=1)
df['outlook']=df['outlook'].replace(to_replace='overcast',value=0)
df['outlook']=df['outlook'].replace(to_replace='rainy',value=1)
df['outlook']=df['outlook'].replace(to_replace='sunny',value=2)
df
# Out:
#     outlook  temperature  humidity  windy  play
# 0         0            0         0      0     1
# 1         0            2         1      1     1
# 2         0            1         0      1     1
# 3         0            0         1      0     1
# 4         1            1         0      0     1
# 5         1            2         1      0     1
# 6         1            2         1      1     0
# 7         1            1         1      0     1
# 8         1            1         0      1     0
# 9         2            0         0      0     0
# 10        2            0         0      1     0
# 11        2            1         0      0     0
# 12        2            2         1      0     1
# 13        2            1         1      1     1

# %%
X= df.drop(columns=['play'])
y=df['play']
# Out:
# play

# %%
# 4. Split data set into training and testing
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,)

# %%
# 5. Choose a class of model by importing the appropriate estimator class from Scikit- Learn.
dct = DecisionTreeClassifier()

# %%
# 7. Fit the model to your training data by calling the fit() method of the model instance.
dct.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 8. Test the classifier on Test data
y_hat = dct.predict(X_test)

# %%
# 9. Compare predicted output with actual output to find accuracy
from sklearn.metrics import accuracy_score, confusion_matrix
print(accuracy_score(y_test,y_hat))
print(confusion_matrix(y_test,y_hat))
# Out:
# 0.6
# [[1 1]
#  [1 2]]

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dct, filled=True, feature_names=X.columns, class_names=y.name, rounded=True)
plt.show()
