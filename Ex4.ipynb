# %% [markdown]
# <a href="https://colab.research.google.com/github/jashasmani/DAUP/blob/main/Ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import sklearn.datasets as data

iris =data.load_iris()

# %%
import sklearn.datasets as data

iris =data.load_iris()
plt.scatter(x=iris.data[:,0], y=iris.data[:,1])

# %%
plt.hist(iris.data[:,0],10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(iris.data[:,0])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e95411a7700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e95411a7c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e95411a7460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e95411dc1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e95411dc460>],
#  'means': []}
